# %%
import pandas as pd
# Read Excel file

data = pd.read_excel("asn-data.xlsx", "GenInfo (2)")
# df
# Out:
# /Users/Cam/PycharmProjects/personalWebsite/venv/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
# Create DataFrame variable and drop columns

df = pd.DataFrame(data)
columns_to_keep = ['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 15',
                   'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 21', 'Unnamed: 27',
                   'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
                   'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 39', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43',
                   'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50',
                   'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54', ]
# size = len(columns_to_keep)
# print(size)
df.drop(df.columns.difference(columns_to_keep), 1, inplace=True)
# df
# Out:
# /var/folders/nk/bm25bxs96tvdcssyqndn5lv00000gp/T/ipykernel_2965/3152441729.py:12: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df.drop(df.columns.difference(columns_to_keep), 1, inplace=True)

# %%
# drop rows

df.drop(df.index[[0, 1, 2, 4, 5]], inplace=True)
df.loc[3, 'Unnamed: 42'] = 'Et®hn'
# df

# %%
# drop empty rows at the end of file

df = df.iloc[:51]
df
# Out:
#    Unnamed: 2  Unnamed: 3                             Unnamed: 4 Unnamed: 5  \
# 3   LAST NAME  FIRST NAME                                 SCHOOL   DCFS ID#
# 6    Sample01   Student01                     Antonia Pantoja Hs   N5996686
# 7    Sample02   Student02                     Antonia Pantoja Hs   N7996585
# 8    Sample03   Student03                     Antonia Pantoja Hs   Y5686785
# 9    Sample03   Student03                     Antonia Pantoja Hs   Y5686785
# 10   Sample04   Student04              Asn Preparatory Institute   T6798567
# 11   Sample05   Student05              Asn Preparatory Institute   U6678589
# 12   Sample06   Student06              Asn Preparatory Institute   Z5558985
# 13   Sample07   Student07                   Association House Hs   S7776988
# 14   Sample08   Student08                   Association House Hs   W7996985
# 15   Sample09   Student09                        Chatham Academy   S7896885
# ...

# %%
df.columns = df.iloc[0]
df = df.iloc[1:].reset_index(drop=True)
df.head()
# Out:
# 3 LAST NAME  FIRST NAME                     SCHOOL  DCFS ID#  \
# 0  Sample01   Student01         Antonia Pantoja Hs  N5996686
# 1  Sample02   Student02         Antonia Pantoja Hs  N7996585
# 2  Sample03   Student03         Antonia Pantoja Hs  Y5686785
# 3  Sample03   Student03         Antonia Pantoja Hs  Y5686785
# 4  Sample04   Student04  Asn Preparatory Institute  T6798567
#
# 3      EMAIL ADDRESS       PHONE # OFFICIALLY PENDING START  \
# 0  SSample01@asn.com  773-555-0001                      NaN
# 1  SSample02@asn.com  773-555-0002                      NaN
# 2  SSample03@asn.com  773-555-0003                      NaN
# 3  SSample03@asn.com  773-555-0003                      NaN
# 4  SSample04@asn.com  773-555-0004                      NaN
#
# 3 OFFICIALLY PENDING END REFERRAL END STATUS REFERRAL END STATUS DATE  ...  \
# 0                    NaN                 NaN                      NaN  ...
# 1                    NaN                 NaN                      NaN  ...
# ...

# %%
# clean columns
df[["Caseworker First Name", "Caseworker Last Name"]] = df["Current Caseworker Name"].str.split(" ", expand = True)
df["Street Address"] = df["Street Address"] + df["Unit / Suite #"]

df.drop(['Unit / Suite #', "Current Caseworker Name", "DAYS at current placement"], axis=1, inplace = True)

salesforce_meta_data = ["OFFICIALLY PENDING START", "OFFICIALLY PENDING END", "REFERRAL END STATUS", "REFERRAL END STATUS DATE" "IF NOT ACCEPTED OR NOT APPROVED BY DCFS, PLEASE PROVIDE REASON",]

# %%
# Rename the columns to match Salesforce
renaming_dict = {
    "FIRST NAME" : "Student First Name",
    "LAST NAME" : "Student Last Name",
    "DCFS ID#" : "DCFS ID",
    "EMAIL ADDRESS" : "Student Email",
    "PHONE #" : "Student Phone",
    "ENROLLMENT DATE": "Date Enrolled",
    "Number of Previous HS" : "Number of previous high schools",
    "Numnber of DAYS out of school" : "Number of days out of school",
    "Number of Placements" : "Total Number of Placements",
    "Phone": "Caseworker Phone Number",
    "Email": "Caseworker Email",
    "Agency": "Caseworker Agency",
    "Street Address": "Caseworker Street Address",
    "City": "Caseworker City",
    "State": "Caseworker State",
    "Zip": "Caseworker Zip Code",
    "DOB": "Student DOB",
    "Et®hn": "Student Ethnicity",
    "LIVING SITUATION": "Student Living Situation Type",
    "Number of DAYS out of school": "Number of days out of school",
    "SpecEd" : "Special Needs Status",
    "DUE DATE IF PREGNANT?": "Student Pregnancy Due Date",
    "# CHILDREN" : "Number of children",
    "Grade at Entry": "Grade Level",
    "SCHOOL": "Schools"
}
df.rename(columns=renaming_dict, inplace=True)
df.columns
# Out:
# Index(['Student Last Name', 'Student First Name', 'Schools', 'DCFS ID',
#        'Student Email', 'Student Phone', 'OFFICIALLY PENDING START',
#        'OFFICIALLY PENDING END', 'REFERRAL END STATUS',
#        'REFERRAL END STATUS DATE',
#        'IF NOT ACCEPTED OR NOT APPROVED BY DCFS, PLEASE PROVIDE REASON',
#        'Date Enrolled', 'Caseworker Phone Number', 'Caseworker Email',
#        'Caseworker Agency', 'Caseworker Street Address', 'Caseworker City',
#        'Caseworker State', 'Caseworker Zip Code', 'Student DOB',
#        'Student Gender', 'Student Ethnicity', 'Student Living Situation Type',
#        'Number of previous high schools', 'Number of days out of school',
#        'Total Number of Placements', 'Grade Level', 'Special Needs Status',
#        'TP Entry', 'TP To Date', 'Student Pregnancy Due Date',
#        'Number of children', 'Caseworker First Name', 'Caseworker Last Name'],
#       dtype='object', name=3)

# %%
# Map columns to objects

student_contact_df = df[["Student Last Name", "Student First Name", 'Student Email','Student Phone', 'Student DOB', 'Student Gender']]
ys3_referral_form_df = df
ys3_columns = [column for column in list(df.columns) if column not in list(student_contact_df.columns)] 
ys3_program_df = df[ys3_columns]
student_contact_df["Student Contact Record"] = student_contact_df["Student Last Name"] + student_contact_df["Student First Name"]


ys3_program_df
student_contact_df
# Out:
# /Users/Cam/PycharmProjects/personalWebsite/venv/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
# 3  Student Last Name Student First Name      Student Email Student Phone  \
# 0           Sample01          Student01  SSample01@asn.com  773-555-0001
# 1           Sample02          Student02  SSample02@asn.com  773-555-0002
# 2           Sample03          Student03  SSample03@asn.com  773-555-0003
# 3           Sample03          Student03  SSample03@asn.com  773-555-0003
# 4           Sample04          Student04  SSample04@asn.com  773-555-0004
# 5           Sample05          Student05  SSample05@asn.com  773-555-0005
# ...

# %%
# Map dataframes to Contact dataframe

contact_df = student_contact_df.rename(columns={"Student Last Name": "Contact: Last Name",
                                              "Student First Name": "Contact: First Name",
                                              "Student Email": "Contact: Email",
                                              'Student Phone': "Contact: Phone",
                                               'Student DOB': "Contact: Birthdate",
                                               'Student Gender': "Contact: Gender"})
contact_df = contact_df + ys3_program_df.rename(columns={"DCFS ID": "Contact: DCFS ID",
                                                        "Student Ethnicity": "Contact: Ethnicity",
                                                         "Studen Living Situation Type": "Contact: Current Living Status",
                                                         "DAYS at current placement": "Contact: Days At Current Placement",
                                                         "Special Needs Status": "Contact:Special Needs Status",
                                                         "Student Pregancy Due Date": "Contact: Pregnancy Due Date"
                                                        })
contact_df["Contact: Pregnant"] = ['Y' for status in ys3_program_df["TP To Date"]]

# %%
# save as csv

df.to_excel('asn_clean_data.xlsx', index=True)
df.to_csv('asn_clean_data.csv', index=True)
student_contact_df.to_csv('student_contact_clean_data.csv', index=True)
referral_form_df.to_csv('ys3_referral_form_clean_data.csv', index=True)
contact_df.to_csv('contact_clean_data.csv', index=True)
ys3_program_df.to_csv('ys3_program_clean_data.csv', index=True)
